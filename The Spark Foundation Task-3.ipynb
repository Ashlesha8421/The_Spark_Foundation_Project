# %% [markdown]
# ## Data Science and Business Analytics Internship
# ##  GRIP : The Sparks Foundation
# ## Author : Ashlesha Datir
# ## Task 3: Exploratory Data Analysis - Retail
#
# **Q) As a business manager, try to find out the weak areas where you can work to make more profit. and What all business problems you can derive by exploring the data?**
#
# **Dataset is avilable at:https://bit.ly/3i4rbWl**

# %%
# Importing required libraries.
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
import warnings
warnings.filterwarnings('ignore')

# %%
#Import the dataset 
df= pd.read_csv("SampleSuperstore.csv")
print("Data import successfully")
# Out:
# Data import successfully

# %%
# Check first five records
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ###  Cleaning and Exporting the data

# %%
# To check more information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
# To check data structure
df.shape
# Out:
# (9994, 13)

# %%
# To describe the data using stats
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
# To check null values
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# **There is no null values in our dataset**

# %%
# To check the duplicate records
duplicate_rows = df[df.duplicated()]
print('Number of duplicate rows: ', duplicate_rows.shape)
# Out:
# Number of duplicate rows:  (17, 13)

# %%
# Drop the duplicate records
df1 = df.drop_duplicates().reset_index(drop=True)
print("Shape of the data:",df1.shape)
df1.head()
# Out:
# Shape of the data: (9977, 13)
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df1.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# **From above "Country" has only one unique value and "Postal Code" is not necessary for our analysis so we drop these columns**

# %%
# Drop these column
df1 = df1.drop(columns={'Country','Postal Code'},axis=1)
df1.head()
# Out:
#         Ship Mode    Segment             City       State Region  \
# 0    Second Class   Consumer        Henderson    Kentucky  South
# 1    Second Class   Consumer        Henderson    Kentucky  South
# 2    Second Class  Corporate      Los Angeles  California   West
# 3  Standard Class   Consumer  Fort Lauderdale     Florida  South
# 4  Standard Class   Consumer  Fort Lauderdale     Florida  South
#
#           Category Sub-Category     Sales  Quantity  Discount    Profit
# 0        Furniture    Bookcases  261.9600         2      0.00   41.9136
# 1        Furniture       Chairs  731.9400         3      0.00  219.5820
# 2  Office Supplies       Labels   14.6200         2      0.00    6.8714
# 3        Furniture       Tables  957.5775         5      0.45 -383.0310
# 4  Office Supplies      Storage   22.3680         2      0.20    2.5164

# %%
# Group by
category_sales_profit = df1.groupby('Category').sum()
display(category_sales_profit)
# Out:
#                        Sales  Quantity  Discount       Profit
# Category
# Furniture        741306.3133      8020    368.59   18421.8137
# Office Supplies  718735.2440     22861    946.20  122364.6608
# Technology       836154.0330      6939    244.40  145454.9481

# %%
# Sales,Quantity,Discount and profit of categories
plt.style.use('seaborn-darkgrid')
#colors
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
category_sales_profit.plot.pie(colors = colors,shadow = True, startangle=90, subplots=True,figsize=(50,20),autopct='%1.1f%%')
plt.rcParams['font.size'] =25.0
plt.show()

# %% [markdown]
# **From The Above Bar Chart :**
# - **For total Sales % By Technology is 36.4% & Quantity is 18.3% , Discount is 15.7% and Profit is 50.8%**
# - **For total Sales % By Office Supplies is 31.3% & Quantity is 60.4% , Discount is 60.7% and Profit is 42.7%**
# - **For total Sales % By Furniture is 32.3% & Quantity is 21.2% , Discount is 23.6% and Profit is 6.4%**

# %%
Subcategory_sales_profit = df1.groupby('Sub-Category').sum()
display(Subcategory_sales_profit)
# Out:
#                     Sales  Quantity  Discount      Profit
# Sub-Category
# Accessories   167380.3180      2976     60.80  41936.6357
# Appliances    107532.1610      1729     77.60  18138.0054
# Art            27107.0320      2996     59.60   6524.6118
# Binders       203409.1690      5971    566.20  30228.0003
# Bookcases     114879.9963       868     48.14  -3472.5560
# Chairs        327777.7610      2351    104.70  26567.1278
# Copiers       149528.0300       234     11.00  55617.8249
# Envelopes      16476.4020       906     20.40   6964.1767
# Fasteners       3024.2800       914     17.80    949.5182
# Furnishings    91683.0240      3560    132.40  13052.7230
# Labels         12444.9120      1396     25.00   5526.3820
# Machines      189238.6310       440     35.20   3384.7569
# Paper          78224.1420      5144    101.80  33944.2395
# Phones        330007.0540      3289    137.40  44515.7306
# Storage       223843.6080      3158     63.20  21278.8264
# Supplies       46673.5380       647     14.60  -1189.0995
# Tables        206965.5320      1241     83.35 -17725.4811

# %%
#Sales and Profits of Categories and Sub-Categories
fig=plt.figure(figsize=(15,8))
ax1=fig.add_subplot(121)
ax2=fig.add_subplot(122)
df1.groupby("Category")[["Sales","Profit"]].sum().sort_values(by="Sales",ascending=False).plot(kind="bar",ax=ax1)
ax1.set_title("Sales and Profits for each Category",size=18)
df1.groupby("Sub-Category")[["Sales","Profit"]].sum().sort_values(by ="Sales",ascending=False).plot(kind ="bar",ax=ax2)
ax2.set_title("Sales and Profits for each Sub-Category",size=18)
plt.show()

# %% [markdown]
# **From plot 1 :**
# - In Category the **maximum profit** is for **Technology** with sales around 836K and the **minimum Profit**  for category **Furniture** with sales around 741K
#
# **From plot 2 :**
# - In Subcategory the **maximum profit** is for **Copiers** with sales nearly 150K and the profit is negative for sub category **Tables** with sales nearly 206K

# %%
# group by quantity , sales and profit
Quantity_sales_profit = df1.groupby('Quantity').sum() 
display(Quantity_sales_profit)
# Out:
#                 Sales  Discount      Profit
# Quantity
# 1          53251.9345    137.51   7440.4801
# 2         288786.7798    371.47  38450.6180
# 3         421514.1507    367.97  56928.7335
# 4         323516.8744    187.83  44152.3740
# 5         415661.6965    193.29  49516.5945
# 6         207122.3214     95.27  10325.4678
# 7         239908.3659     98.16  34286.9730
# 8         117760.1760     44.10  10856.7960
# 9         128505.5901     38.17  17687.8908
# 10         24056.6640     10.87   2044.1570
# 11         15772.4820      3.30   4293.3671
# 12         14868.4080      2.60   1185.0660
# 13         32338.1890      4.25   6348.9010
# 14         13131.9580      4.40   2724.0038

# %%
Segment_sales_profit=df1.groupby('Segment').sum()
display(Segment_sales_profit)
# Out:
#                     Sales  Quantity  Discount       Profit
# Segment
# Consumer     1.160833e+06     19497    820.51  134007.4413
# Corporate    7.060701e+05     11591    476.85   91954.9798
# Home Office  4.292927e+05      6732    261.83   60279.0015

# %%
#Sales and Profits of each Quantity and each Segment
fig=plt.figure(figsize=(15,8))
ax1=fig.add_subplot(121)
ax2=fig.add_subplot(222)
df1.groupby("Quantity")[["Sales", "Profit"]].sum().sort_values(by = "Sales", ascending = False).plot(kind = "bar",ax=ax1)
ax1.set_title("Sales and Profits for each Quantity",size=18)
df1.groupby("Segment")[["Sales", "Profit"]].sum().sort_values(by = "Sales", ascending = False).plot(kind = "bar",ax=ax2)
ax2.set_title("Sales and Profits for each Segment",size=18)
plt.show()

# %% [markdown]
# **From plot 1 :**
# - The **sales is maximum** for **lesser quantities** and **so is the profit.**
#
# **From plot 2 :**
# - The **maximum profit** in *Segment** the **consumer** having  **maximum sales** and the **profit** is **minimum** for segment **Home office** with minimum sales amongst the segment.

# %%
#Sales and Profits of each State
fig=plt.figure(figsize=(50,20))
ax1=fig.add_subplot(121)
df1.groupby("State")[["Sales","Profit"]].sum().sort_values(by = "Sales", ascending = False).plot(kind = "bar",ax=ax1)
ax1.set_title("Sales and Profits for each State", size=28)
plt.show()

# %% [markdown]
# **From above :**
# - for states including Texas,Pennsylvania, Florida, Illinois, Ohio, North Carolina and few other states have high sales with negative profits.

# %%
#statewise discount
df1.groupby("State").sum()['Discount'].sort_values(ascending = False)
# Out:
# State
# Texas                   364.24
# Pennsylvania            192.70
# Illinois                191.10
# Ohio                    152.10
# California              145.60
# Florida                 114.65
# North Carolina           70.60
# Arizona                  68.00
# New York                 62.40
# Colorado                 57.60
# Tennessee                53.30
# Oregon                   35.60
# Washington               32.40
# Utah                      3.20
# Nevada                    2.40
# New Mexico                2.20
# Massachusetts             2.10
# Michigan                  1.80
# Idaho                     1.80
# Rhode Island              1.20
# Montana                   1.00
# Delaware                  0.60
# New Jersey                0.60
# Connecticut               0.60
# Maryland                  0.60
# New Hampshire             0.30
# West Virginia             0.30
# Wyoming                   0.20
# Minnesota                 0.00
# Georgia                   0.00
# Virginia                  0.00
# Arkansas                  0.00
# Vermont                   0.00
# South Dakota              0.00
# South Carolina            0.00
# Oklahoma                  0.00
# District of Columbia      0.00
# North Dakota              0.00
# Nebraska                  0.00
# Mississippi               0.00
# Wisconsin                 0.00
# Indiana                   0.00
# Iowa                      0.00
# Kansas                    0.00
# Kentucky                  0.00
# Louisiana                 0.00
# Maine                     0.00
# Missouri                  0.00
# Alabama                   0.00
# Name: Discount, dtype: float64

# %% [markdown]
# By comparing the barplot and the above dataframe, we can observe that the states that are offered high discounts are generating less profits

# %%
# data frame of statewise sales,profit,discount
states_data = df1.groupby("State")[["Sales","Profit","Discount"]].sum().sort_values(by = "Sales", ascending = False)
states_data.head()
# Out:
#                     Sales      Profit  Discount
# State
# California    457576.2715  76330.7891    145.60
# New York      310827.1510  74015.4622     62.40
# Texas         170124.5418 -25750.9833    364.24
# Washington    138560.8100  33368.2375     32.40
# Pennsylvania  116496.3620 -15565.4035    192.70

# %%
#Discount with Negative Profit
states_data['Discount'][states_data['Profit'] < 0].sort_values(ascending = True)
# Out:
# State
# Oregon             35.60
# Tennessee          53.30
# Colorado           57.60
# Arizona            68.00
# North Carolina     70.60
# Florida           114.65
# Ohio              152.10
# Illinois          191.10
# Pennsylvania      192.70
# Texas             364.24
# Name: Discount, dtype: float64

# %%
#line plot
sns.lineplot(x = "Discount", y = "Profit", data = df1, color = "blue",linestyle='dashed')
plt.show()

# %% [markdown]
# **From above :**
# - We can clearly observe that **discount** has a **negative relation** with **Profit** i.e. as the discount is increasing the Profit generated is decreased.

# %%
# Categorywise sales and profit and their counts
cat_data = df1.groupby("Category")[["Sales","Profit"]].sum().sort_values(by = "Sales",ascending = False)
cat_data['value_counts'] = df1['Category'].value_counts()
display(cat_data)
# Out:
#                        Sales       Profit  value_counts
# Category
# Technology       836154.0330  145454.9481          1847
# Furniture        741306.3133   18421.8137          2118
# Office Supplies  718735.2440  122364.6608          6012

# %%
#Sales in terms of Categories in different Regions
plt.figure(figsize=(12,6))
sns.barplot(x='Category',y='Sales',hue='Region',data=df1)
plt.title("Sales in terms of Categories in different Regions",size=20)
plt.show()

# %% [markdown]
# **From Above :**
# - The sales of "Furniture" is done maximum in Western Region nearly about 360k+,
# - and the sales of "Office Supplies" is maximum done in South region nearly about 150k+
# - and then the sales of "Technology" is maximum done in South Region nearly about 550k+.
# - Among all the three Category, the sale of Technology is Max and also Maximum Sales is done in South region.

# %%
#Sales in terms of Categories in different Shipmode
plt.figure(figsize=(12,6))
sns.barplot(x='Category',y='Sales',hue='Ship Mode',data=df1)
plt.title("Sales in terms of Categories in different Shipmode",size=20)
plt.show()

# %% [markdown]
# **From Above :**
# - According to the class,
# - The sales of "Furniture" is done maximum in Second Class,
# - after that, the sales of "Office Supplies" is maximum done in Second Class.
# - and the sales of "Technology" is maximum done in Same Day.
# - Among all the three Category, the sale of Technology is Max and also Maximum Sales is done in Same Day.

# %% [markdown]
# ### data with respect to negative profits

# %%
Negative_profits=df1.loc[df1.Profit <= 0].sort_values(by = "Profit",ascending = True).reset_index(drop=True)
Negative_profits.head(10)
# Out:
#         Ship Mode      Segment          City           State   Region  \
# 0  Standard Class     Consumer     Lancaster            Ohio     East
# 1        Same Day    Corporate    Burlington  North Carolina    South
# 2  Standard Class     Consumer   San Antonio           Texas  Central
# 3  Standard Class  Home Office    Louisville        Colorado     West
# 4  Standard Class    Corporate       Chicago        Illinois  Central
# 5     First Class     Consumer        Newark            Ohio     East
# 6     First Class     Consumer       Houston           Texas  Central
# 7    Second Class     Consumer       Concord  North Carolina    South
# 8  Standard Class     Consumer       Houston           Texas  Central
# 9  Standard Class  Home Office  Jacksonville         Florida    South
#
#           Category Sub-Category      Sales  Quantity  Discount     Profit
# 0       Technology     Machines   4499.985         5       0.7 -6599.9780
# 1       Technology     Machines   7999.980         4       0.5 -3839.9904
# 2  Office Supplies      Binders   2177.584         8       0.8 -3701.8928
# 3       Technology     Machines   2549.985         5       0.7 -3399.9800
# 4  Office Supplies      Binders   1889.990         5       0.8 -2929.4845
# 5       Technology     Machines   1799.994         2       0.7 -2639.9912
# 6  Office Supplies      Binders   1525.188         6       0.8 -2287.7820
# 7        Furniture       Tables   4297.644        13       0.4 -1862.3124
# 8  Office Supplies      Binders   1088.792         4       0.8 -1850.9464
# 9       Technology     Machines  22638.480         6       0.5 -1811.0784

# %%
#Negative Profit by Category
by_cat=Negative_profits.groupby('Category').sum().reset_index()
by_cat
# Out:
#           Category        Sales  Quantity  Discount      Profit
# 0        Furniture  276601.4618      2775    269.74 -60924.0502
# 1  Office Supplies  100054.7190      3533    546.60 -56609.0215
# 2       Technology  119452.8850       982     90.60 -38579.9182

# %%
plt.subplots(figsize=(10,2))
sns.barplot(y=by_cat.Category,x=by_cat.Profit)
plt.title("Negative Profit by Category",size=20)
plt.show()

# %%
#Negative Profits for each Category
fig=plt.figure(figsize=(50,8))
ax1=fig.add_subplot(121)
Negative_profits.groupby("Category")[["Sales","Profit","Quantity"]].sum().sort_values(by = "Sales", ascending = False).plot(kind = "bar",ax=ax1)
ax1.set_title("Negative Profits for each Category",size=30)
plt.show()

# %% [markdown]
# - From the above two bar plots, we observe that **sales** which are **maximum nearly 276K** is causing the **most negative profits nearly -60K.**

# %%
#Negative Profit by City
by_city=Negative_profits.groupby('City').sum().sort_values(by='Profit').reset_index()
by_city.head()
# Out:
#            City       Sales  Quantity  Discount      Profit
# 0  Philadelphia  72620.3450       910    116.30 -19590.7411
# 1       Houston  38565.3744       691    104.74 -14785.3668
# 2       Chicago  20633.6220       547     88.00 -11114.3901
# 3   San Antonio  17952.7300       144     17.40  -7831.0254
# 4     Lancaster   7870.0280        72      9.70  -7632.4946

# %%
#Top 5 Cities with most negative profit
plt.subplots(figsize=(10,2))
sns.barplot(y=by_city.head().City,x=by_city.head().Profit)
plt.title("Top 5 Cities with most negative profit",size=20)
plt.show()

# %% [markdown]
# ### Insights Drawn from Analyzing the SampleSuperstore data
#
# **1)** The profits for the Category Office Supplies is high, but the sales of the Category Office Supplies is less. So, we should focus on increasing the sales for Office Supplies.
#
# **2)** The profits for the sub-category Tables and Bookcases are very less but the profit for sub-category Copiers is very high. So, we should focus on increasing the sales of the copiers.
#
# **3)** The maximum profit is for Segment consumer for maximum sales hence growth must be increased in this segment
#
# **4)** The ship Mode which is Maximum use by customers are Same day and they are doing maximum sales but do not making any much profit. So we receive maximum profit and sales with Standard class ship mode and hence this mode should be used highly.
#
# **5)** The maximum sales is more than 700K for the West region and Profit is maximum in this region so we continue to grow the sales in west region. The minimum profit is present in the Central region where sales is comparatively higher than the south region that has more profit that the central region. Hence sales must be increased in south region as compared to central region for maximum profit.
#
# **6)** States with maximum sales have minimum profits with few giving rise to negative profits, hence more focus should be put on increasing the sales in the states where sales is minimum in the current scenario, to gain more profit.
#
# **7)** States with maximum sales have minimum profits with few giving rise to negative profits, hence more focus should be put on increasing the sales in the states where sales is minimum in the current scenario, to gain more profit.
#
# **8)** The states with high Sales are generating less profit due to high discount allowance. Discount is negatively related to the Profit. This is be noted when a discount is being allowed on the products.
